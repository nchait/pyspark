# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName('aggs').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = sqlContext.sql("SELECT * FROM sales_info_csv")
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+-----+
# Company| Person|Sales|
# +-------+-------+-----+
#    GOOG|    Sam|  200|
#    GOOG|Charlie|  120|
#    GOOG|  Frank|  340|
#    MSFT|   Tina|  600|
#    MSFT|    Amy|  124|
#    MSFT|Vanessa|  243|
#      FB|   Carl|  870|
#      FB|  Sarah|  350|
#    APPL|   John|  250|
#    APPL|  Linda| null|
#    APPL|   Mike| null|
#    APPL|  Chris| null|
# +-------+-------+-----+
#
# </div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Company: string (nullable = true)
# -- Person: string (nullable = true)
# -- Sales: integer (nullable = true)
#
# </div>

# %%
# df.groupBy('Company').count().show()
df.groupBy('Company').sum().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+
# Company|sum(Sales)|
# +-------+----------+
#    APPL|       250|
#    GOOG|       660|
#      FB|      1220|
#    MSFT|       967|
# +-------+----------+
#
# </div>

# %%
# df.agg({'Sales':'max'}).show()
df.agg({'Sales':'sum'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+
# sum(Sales)|
# +----------+
#       3097|
# +----------+
#
# </div>

# %%
gd = df.groupBy("Company")
gd.agg({'Sales':'sum'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+
# Company|sum(Sales)|
# +-------+----------+
#    APPL|       250|
#    GOOG|       660|
#      FB|      1220|
#    MSFT|       967|
# +-------+----------+
#
# </div>

# %%
from pyspark.sql.functions import countDistinct, avg, stddev
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.select(avg('Sales')).alias('averageSales').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#        avg(Sales)|
# +-----------------+
# 344.1111111111111|
# +-----------------+
#
# </div>

# %%
sstd = df.select(stddev('Sales').alias('std'))
sstd.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#                std|
# +------------------+
# 245.10530616678028|
# +------------------+
#
# </div>

# %%
from pyspark.sql.functions import format_number
sstd.select(format_number('std',2).alias('std')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+
#    std|
# +------+
# 245.11|
# +------+
#
# </div>

# %%
df.orderBy('Sales').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+-----+
# Company| Person|Sales|
# +-------+-------+-----+
#    APPL|   Mike| null|
#    APPL|  Linda| null|
#    APPL|  Chris| null|
#    GOOG|Charlie|  120|
#    MSFT|    Amy|  124|
#    GOOG|    Sam|  200|
#    MSFT|Vanessa|  243|
#    APPL|   John|  250|
#    GOOG|  Frank|  340|
#      FB|  Sarah|  350|
#    MSFT|   Tina|  600|
#      FB|   Carl|  870|
# +-------+-------+-----+
#
# </div>

# %%
df.orderBy(df['Sales'].desc()).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------+-----+
# Company| Person|Sales|
# +-------+-------+-----+
#      FB|   Carl|  870|
#    MSFT|   Tina|  600|
#      FB|  Sarah|  350|
#    GOOG|  Frank|  340|
#    APPL|   John|  250|
#    MSFT|Vanessa|  243|
#    GOOG|    Sam|  200|
#    MSFT|    Amy|  124|
#    GOOG|Charlie|  120|
#    APPL|  Linda| null|
#    APPL|   Mike| null|
#    APPL|  Chris| null|
# +-------+-------+-----+
#
# </div>
