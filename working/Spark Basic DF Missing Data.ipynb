# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName('miss').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = sqlContext.sql("SELECT * FROM containsnull_csv")
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John| null|
# emp2| null| null|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.drop().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.drop(thresh=2).show()
# thresh is num of NON NULL
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John| null|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.drop(how='all').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John| null|
# emp2| null| null|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.drop(subset='Sales').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.fill('fillVal').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+-----+
#   Id|   Name|Sales|
# +----+-------+-----+
# emp1|   John| null|
# emp2|fillVal| null|
# emp3|fillVal|345.0|
# emp4|  Cindy|456.0|
# +----+-------+-----+
#
# </div>

# %%
df.na.fill(0).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John|  0.0|
# emp2| null|  0.0|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.fill('fillVal',subset='Name').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+-----+
#   Id|   Name|Sales|
# +----+-------+-----+
# emp1|   John| null|
# emp2|fillVal| null|
# emp3|fillVal|345.0|
# emp4|  Cindy|456.0|
# +----+-------+-----+
#
# </div>

# %%
from pyspark.sql.functions import mean
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
mean_val = df.select(mean(df.Sales)).collect()
mean_val = mean_val[0][0]
df.na.fill(mean_val,subset='Sales').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John|400.5|
# emp2| null|400.5|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>

# %%
df.na.fill(df.select(mean(df.Sales)).collect()[0][0],subset='Sales').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+-----+
#   Id| Name|Sales|
# +----+-----+-----+
# emp1| John|400.5|
# emp2| null|400.5|
# emp3| null|345.0|
# emp4|Cindy|456.0|
# +----+-----+-----+
#
# </div>
